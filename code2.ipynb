# %%
import os
import yaml
import pandas as pd

# Base directory where folders like "10-2023" are located
base_dir = r"C:\Users\vishn\OneDrive\Desktop\project2"

# Loop through each subfolder (e.g., "10-2023", "11-2023", etc.)
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)

 #   Only process directorie
    if os.path.isdir(folder_path):
        #Loop through YAML files in the folder
        for file_name in os.listdir(folder_path):
            if file_name.endswith(".yaml"):
                yaml_file_path = os.path.join(folder_path, file_name)

 # Read and parse YAML file
                with open(yaml_file_path, 'r') as f:
                    try:
                        data = yaml.safe_load(f)
                        if data: # Only proceed if data is not empty
                            df = pd.DataFrame(data)

# Save as CSV with the same name
                            csv_file_name = file_name.replace(".yaml", ".csv")
                            csv_file_path = os.path.join(folder_path, csv_file_name)
                            df.to_csv(csv_file_path, index=False)
                            print(f"Converted: {csv_file_name}")
                        else:
                            print(f"Skipped empty file: {file_name}")
                    except Exception as e:
                        print(f"Error reading {file_name}: {e}")
# Out:
# Converted: 2023-10-03_05-30-00.csv
# Converted: 2023-10-04_05-30-00.csv
# Converted: 2023-10-05_05-30-00.csv
# Converted: 2023-10-06_05-30-00.csv
# Converted: 2023-10-09_05-30-00.csv
# Converted: 2023-10-10_05-30-00.csv
# Converted: 2023-10-11_05-30-00.csv
# Converted: 2023-10-12_05-30-00.csv
# Converted: 2023-10-13_05-30-00.csv
# Converted: 2023-10-16_05-30-00.csv
# Converted: 2023-10-17_05-30-00.csv
# Converted: 2023-10-18_05-30-00.csv
# Converted: 2023-10-19_05-30-00.csv
# Converted: 2023-10-20_05-30-00.csv
# Converted: 2023-10-23_05-30-00.csv
# Converted: 2023-10-25_05-30-00.csv
# Converted: 2023-10-26_05-30-00.csv
# Converted: 2023-10-27_05-30-00.csv
# Converted: 2023-10-30_05-30-00.csv
# Converted: 2023-10-31_05-30-00.csv
# Converted: 2023-11-01_05-30-00.csv
# Converted: 2023-11-02_05-30-00.csv
# Converted: 2023-11-03_05-30-00.csv
# Converted: 2023-11-06_05-30-00.csv
# Converted: 2023-11-07_05-30-00.csv
# Converted: 2023-11-08_05-30-00.csv
# Converted: 2023-11-09_05-30-00.csv
# Converted: 2023-11-10_05-30-00.csv
# Converted: 2023-11-12_05-30-00.csv
# Converted: 2023-11-13_05-30-00.csv
# Converted: 2023-11-15_05-30-00.csv
# Converted: 2023-11-16_05-30-00.csv
# Converted: 2023-11-17_05-30-00.csv
# Converted: 2023-11-20_05-30-00.csv
# Converted: 2023-11-21_05-30-00.csv
# Converted: 2023-11-22_05-30-00.csv
# Converted: 2023-11-23_05-30-00.csv
# Converted: 2023-11-24_05-30-00.csv
# Converted: 2023-11-28_05-30-00.csv
# Converted: 2023-11-29_05-30-00.csv
# Converted: 2023-11-30_05-30-00.csv
# Converted: 2023-12-01_05-30-00.csv
# Converted: 2023-12-04_05-30-00.csv
# Converted: 2023-12-05_05-30-00.csv
# Converted: 2023-12-06_05-30-00.csv
# Converted: 2023-12-07_05-30-00.csv
# Converted: 2023-12-08_05-30-00.csv
# Converted: 2023-12-11_05-30-00.csv
# Converted: 2024-10-16_05-30-00.csv
# Converted: 2024-10-17_05-30-00.csv
# Converted: 2024-10-18_05-30-00.csv
# Converted: 2024-10-21_05-30-00.csv
# Converted: 2024-10-22_05-30-00.csv
# Converted: 2024-10-23_05-30-00.csv
# Converted: 2024-10-24_05-30-00.csv
# Converted: 2024-10-25_05-30-00.csv
# Converted: 2024-10-28_05-30-00.csv
# Converted: 2024-10-29_05-30-00.csv
# Converted: 2024-10-30_05-30-00.csv
# Converted: 2024-10-31_05-30-00.csv
# Converted: 2024-11-01_05-30-00.csv
# Converted: 2024-11-04_05-30-00.csv
# Converted: 2024-11-05_05-30-00.csv
# Converted: 2024-11-06_05-30-00.csv
# Converted: 2024-11-07_05-30-00.csv
# Converted: 2024-11-08_05-30-00.csv
# Converted: 2024-11-11_05-30-00.csv
# Converted: 2024-11-12_05-30-00.csv
# Converted: 2024-11-13_05-30-00.csv
# Converted: 2024-11-14_05-30-00.csv
# Converted: 2024-11-18_05-30-00.csv
# Converted: 2024-11-19_05-30-00.csv
# Converted: 2024-11-21_05-30-00.csv
# Converted: 2024-11-22_05-30-00.csv

# %%
import os
import yaml
import pandas as pd
from collections import defaultdict

# Base directory
base_dir = r"C:\Users\vishn\OneDrive\Desktop\project2"

# Dictionary to collect ticker-wise data
ticker_data = defaultdict(list)

# Loop through each month folder
for folder_name in os.listdir(base_dir):
 folder_path = os.path.join(base_dir, folder_name)

 if os.path.isdir(folder_path):
    print(f"\n Scanning folder: {folder_path}")
    for file_name in os.listdir(folder_path):
       if file_name.endswith(".yaml"):
         yaml_path = os.path.join(folder_path, file_name)
         print(f" Reading file: {yaml_path}")
         with open(yaml_path, 'r') as f:
            try:
               data = yaml.safe_load(f)
               if isinstance(data, list):
                for record in data:
                  ticker = record.get("Ticker")
                  if ticker:
                   ticker_data[ticker].append(record)
                  else:
                    print(f" Missing 'ticker' key in record: {record}")
               else:
                print(f" Unexpected format in {yaml_path}: {type(data)}")
            except Exception as e:
              print(f" Error parsing {yaml_path}: {e}")

# Check how many tickers were found
print(f"\n Total tickers found: {len(ticker_data)}")
print(f" Sample tickers: {list(ticker_data.keys())[:5]}{'...' if
len(ticker_data) > 5 else ''}")

# Output directory
output_dir = os.path.join(base_dir, "Symbol_CSVs")
os.makedirs(output_dir, exist_ok=True)

# Save CSV per ticker
for ticker, records in ticker_data.items():
    df = pd.DataFrame(records)
    output_path = os.path.join(output_dir, f"{ticker}.csv")
    df.to_csv(output_path, index=False)
    print(f" Saved {ticker}.csv with {len(records)} records")
# Out:
#  Scanning folder: C:\Users\vishn\OneDrive\Desktop\project2\2023-10
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-03_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-04_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-05_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-06_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-09_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-10_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-11_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-12_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-13_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-16_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-17_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-18_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-19_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-20_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-23_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-25_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-26_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-27_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-30_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-10\2023-10-31_05-30-00.yaml
#
#  Scanning folder: C:\Users\vishn\OneDrive\Desktop\project2\2023-11
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-01_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-02_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-03_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-06_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-07_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-08_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-09_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-10_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-12_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-13_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-15_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-16_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-17_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-20_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-21_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-22_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-23_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-24_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-28_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-29_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-11\2023-11-30_05-30-00.yaml
#
#  Scanning folder: C:\Users\vishn\OneDrive\Desktop\project2\2023-12
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-01_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-04_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-05_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-06_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-07_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-08_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-11_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-12_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-13_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-14_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-15_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-18_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12-19_05-30-00.yaml
#  Reading file: C:\Users\vishn\OneDrive\Desktop\project2\2023-12\2023-12
#  Saved WIPRO.csv with 284 records
#  Saved TECHM.csv with 284 records
#  Saved NTPC.csv with 284 records
#  Saved HINDUNILVR.csv with 284 records
#  Saved APOLLOHOSP.csv with 284 records
#  Saved M&M.csv with 284 records
#  Saved GRASIM.csv with 284 records
#  Saved ICICIBANK.csv with 284 records
#  Saved ADANIENT.csv with 284 records
#  Saved ADANIPORTS.csv with 284 records
#  Saved BEL.csv with 284 records
#  Saved BAJAJFINSV.csv with 284 records
#  Saved EICHERMOT.csv with 284 records
#  Saved COALINDIA.csv with 284 records
#  Saved MARUTI.csv with 284 records
#  Saved INDUSINDBK.csv with 284 records
#  Saved ASIANPAINT.csv with 284 records
#  Saved TATASTEEL.csv with 284 records
#  Saved HDFCLIFE.csv with 284 records
#  Saved DRREDDY.csv with 284 records
#  Saved SUNPHARMA.csv with 284 records
#  Saved KOTAKBANK.csv with 284 records
#  Saved SHRIRAMFIN.csv with 284 records
#  Saved NESTLEIND.csv with 284 records
#  Saved ONGC.csv with 284 records
#  Saved CIPLA.csv with 284 records
#  Saved BPCL.csv with 284 records
#  Saved BRITANNIA.csv with 284 records
#  Saved SBILIFE.csv with 284 records
#  Saved HINDALCO.csv with 284 records
#  Saved HEROMOTOCO.csv with 284 records
#  Saved AXISBANK.csv with 284 records
#  Saved HDFCBANK.csv with 284 records
#  Saved BAJAJ-AUTO.csv with 284 records

# %%
import os
import pandas as pd

input_folder = r"C:\Users\vishn\OneDrive\Desktop\project2\Symbol_CSVs"
output_folder = r"C:\Users\vishn\OneDrive\Desktop\project2\symbol_csvs_cleaned"
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.endswith(".csv"):
        file_path = os.path.join(input_folder, filename)
        df = pd.read_csv(file_path)

# Ensure 'date' is in datetime format
        df['date'] = pd.to_datetime(df['date'])

# Sort by date
        df = df.sort_values('date')

# Drop duplicates
        df = df.drop_duplicates()

# Optional: Reset index
        df = df.reset_index(drop=True)

# Save cleaned CSV
        cleaned_path = os.path.join(output_folder, filename)
        df.to_csv(cleaned_path, index=False)

        print(f"Cleaned and saved: {filename}")
# Out:
# Cleaned and saved: ADANIENT.csv
# Cleaned and saved: ADANIPORTS.csv
# Cleaned and saved: APOLLOHOSP.csv
# Cleaned and saved: ASIANPAINT.csv
# Cleaned and saved: AXISBANK.csv
# Cleaned and saved: BAJAJ-AUTO.csv
# Cleaned and saved: BAJAJFINSV.csv
# Cleaned and saved: BAJFINANCE.csv
# Cleaned and saved: BEL.csv
# Cleaned and saved: BHARTIARTL.csv
# Cleaned and saved: BPCL.csv
# Cleaned and saved: BRITANNIA.csv
# Cleaned and saved: CIPLA.csv
# Cleaned and saved: COALINDIA.csv
# Cleaned and saved: DRREDDY.csv
# Cleaned and saved: EICHERMOT.csv
# Cleaned and saved: GRASIM.csv
# Cleaned and saved: HCLTECH.csv
# Cleaned and saved: HDFCBANK.csv
# Cleaned and saved: HDFCLIFE.csv
# Cleaned and saved: HEROMOTOCO.csv
# Cleaned and saved: HINDALCO.csv
# Cleaned and saved: HINDUNILVR.csv
# Cleaned and saved: ICICIBANK.csv
# Cleaned and saved: INDUSINDBK.csv
# Cleaned and saved: INFY.csv
# Cleaned and saved: ITC.csv
# Cleaned and saved: JSWSTEEL.csv
# Cleaned and saved: KOTAKBANK.csv
# Cleaned and saved: LT.csv
# Cleaned and saved: M&M.csv
# Cleaned and saved: MARUTI.csv
# Cleaned and saved: NESTLEIND.csv
# Cleaned and saved: NTPC.csv
# Cleaned and saved: ONGC.csv
# Cleaned and saved: POWERGRID.csv
# Cleaned and saved: RELIANCE.csv
# Cleaned and saved: SBILIFE.csv
# Cleaned and saved: SBIN.csv
# Cleaned and saved: SHRIRAMFIN.csv
# Cleaned and saved: SUNPHARMA.csv
# Cleaned and saved: TATACONSUM.csv
# Cleaned and saved: TATAMOTORS.csv
# Cleaned and saved: TATASTEEL.csv
# Cleaned and saved: TCS.csv
# Cleaned and saved: TECHM.csv
# Cleaned and saved: TITAN.csv
# Cleaned and saved: TRENT.csv
# Cleaned and saved: ULTRACEMCO.csv
# Cleaned and saved: WIPRO.csv

# %%
import os
import pandas as pd

# Define the folder where symbol-wise CSVs are stored
data_folder = r"C:\Users\vishn\OneDrive\Desktop\project2\symbol_csvs_cleaned"
output_folder = r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv"
os.makedirs(output_folder, exist_ok=True)

volatility_list = []

# Loop through each CSV in the folder
for filename in os.listdir(data_folder):
    if filename.endswith(".csv"):
        file_path = os.path.join(data_folder, filename)
        ticker = os.path.splitext(filename)[0]# Get ticker from filename

        df = pd.read_csv(file_path)

 # Make sure data is sorted by date
        df['date'] = pd.to_datetime(df['date'])
        df.sort_values('date', inplace=True)

# Calculate daily returns
        df['daily_return'] = df['close'].pct_change()

# Calculate standard deviation (volatility)
        volatility = df['daily_return'].std()
 # Append to the list
        volatility_list.append({'Ticker': ticker, 'Volatility': volatility})

# Create a dataframe from the list
vol_df = pd.DataFrame(volatility_list)

# Sort by Volatility descending
vol_df.sort_values(by='Volatility', ascending=False, inplace=True)

# Save top 10 most volatile stocks to CSV
output_path = os.path.join(output_folder, "volatility.csv")
vol_df.to_csv(output_path, index=False)

print(" Volatility analysis completed and saved at:", output_path)
# Out:
#  Volatility analysis completed and saved at: C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\volatility.csv

# %%
import os
import pandas as pd

# Define input folder and output file path
input_folder = r"C:\Users\vishn\OneDrive\Desktop\project2\Symbol_CSVs"
output_file = r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\cumulative_returns.csv"

# Create output folder if not exist
os.makedirs(os.path.dirname(output_file), exist_ok=True)

# Store cumulative returns for all stocks
all_cumulative_returns = []

# Process each symbol CSV
for filename in os.listdir(input_folder):
    if filename.endswith(".csv"):
        symbol = filename.replace(".csv", "")
        file_path = os.path.join(input_folder, filename)

# Read CSV
        df = pd.read_csv(file_path)

# Ensure it's sorted by date
        df = df.sort_values("date")

# Calculate daily returns
        df['daily_return'] = df['close'].pct_change()
 # Calculate cumulative return
        df['cumulative_return'] = (1 + df['daily_return']).cumprod()

# Add symbol column
        df['symbol'] = symbol

# Append relevant columns to final list
        all_cumulative_returns.append(df[['date', 'symbol', 'cumulative_return']])

# Concatenate all into one DataFrame
final_df = pd.concat(all_cumulative_returns, ignore_index=True)

# Save to CSV
final_df.to_csv(output_file, index=False)

print(f"Cumulative returns saved to: {output_file}")
# Out:
# Cumulative returns saved to: C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\cumulative_returns.csv

# %%
import pandas as pd

#  Load cumulative returns
cumulative_df =pd.read_csv(r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\cumulative_returns.csv")

#  Load and clean sector data
sector_df = pd.read_csv(r"C:\Users\vishn\OneDrive\Desktop\project2\Sector_data - Sheet1.csv")

# Extract only ticker from 'Symbol' column (e.g., "Infosys Ltd: INFY" → "INFY")
sector_df['ticker'] = sector_df['Symbol'].apply(lambda x:
x.split(':')[-1].strip())

#  Optional: Save cleaned sector data for reuse
sector_cleaned_path = r"C:\Users\vishn\OneDrive\Desktop\project2\Sector_data_cleaned.csv"
sector_df.to_csv(sector_cleaned_path, index=False)
print(" Cleaned sector file saved at:", sector_cleaned_path)

#  Rename cumulative_df column for merge
cumulative_df.rename(columns={'symbol': 'ticker'}, inplace=True)

#  Merge on 'ticker'
merged_df = pd.merge(cumulative_df, sector_df, on='ticker', how='left')

# Drop rows with missing sector info
merged_df.dropna(subset=['sector'], inplace=True)

#  Group by sector and calculate average cumulative return
sector_performance = merged_df.groupby('sector')['cumulative_return'].mean().reset_index()

# Sort for readability
sector_performance.sort_values(by='cumulative_return', ascending=False, inplace=True)

#  Save sector performance
output_path = r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\sector_performance.csv"
sector_performance.to_csv(output_path, index=False)

print(" Sector-wise performance saved at:", output_path)
# Out:
#  Cleaned sector file saved at: C:\Users\vishn\OneDrive\Desktop\project2\Sector_data_cleaned.csv
#  Sector-wise performance saved at: C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\sector_performance.csv

# %%
import os
import pandas as pd
from glob import glob

# Step 1: Load all CSVs and align close prices by date
data_dir = r"C:\Users\vishn\OneDrive\Desktop\project2\symbol_csvs_cleaned"
csv_files = glob(os.path.join(data_dir, "*.csv"))

all_data = []

for file in csv_files:
    df = pd.read_csv(file, usecols=['date', 'close'])
    ticker = os.path.splitext(os.path.basename(file))[0]
    df['date'] = pd.to_datetime(df['date'])
    df = df.rename(columns={'close': ticker})
    all_data.append(df.set_index('date'))

# Step 2: Merge all close prices into one DataFrame
merged_df = pd.concat(all_data, axis=1)
merged_df = merged_df.sort_index()

# Step 3: Calculate daily percentage change
returns_df = merged_df.pct_change().dropna()

# Step 4: Calculate correlation matrix
correlation_matrix = returns_df.corr()

# Step 5: Save correlation matrix
output_path = r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\correlation_matrix.csv"
correlation_matrix.to_csv(output_path)

print(" Correlation matrix saved at:", output_path)
# Out:
#  Correlation matrix saved at: C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\correlation_matrix.csv

# %%
import pandas as pd
from pathlib import Path

# Paths
symbol_folder = Path(r"C:\Users\vishn\OneDrive\Desktop\project2\symbol_csvs_cleaned")
output_folder = Path(r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv")
output_folder.mkdir(exist_ok=True)

monthly_returns = []

# Loop through all stock CSVs
for file in symbol_folder.glob("*.csv"):
    df = pd.read_csv(file)
    df['date'] = pd.to_datetime(df['date'])
    df.sort_values('date', inplace=True)
    df['month'] = df['date'].dt.to_period('M')
    ticker = df['Ticker'].iloc[0]

# Get first and last close of each month
    grouped = df.groupby('month').agg(first_close=('close', 'first'), last_close=('close', 'last')).reset_index() 
    grouped['return'] = (grouped['last_close'] - grouped['first_close']) / grouped['first_close'] * 100
    grouped['ticker'] = ticker

monthly_returns.append(grouped)

# Combine and save
all_monthly_returns_df = pd.concat(monthly_returns, ignore_index=True)
all_monthly_returns_df.to_csv(output_folder / "monthly_returns.csv",
index=False)

# %%
connection = mysql.connector.connect(
  host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
  port = 4000,
  user = "4DqqoiZXMnHx5MN.root",
  password = "slTX44fETn8MvbcN",
  database = "IMDB",
  3wJPqKRiThuBOBDz

# %%
import mysql.connector
import pandas as pd

#  Database Connection
conn = mysql.connector.connect(
host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
port=4000,
user="4DqqoiZXMnHx5MN.root",
password="3wJPqKRiThuBOBDz",
database="Stock",
ssl_disabled=False # Required for secure connection
)
cursor = conn.cursor()

#  Create Table if not exists
create_table_query = """
CREATE TABLE IF NOT EXISTS volatility_analysis (ticker VARCHAR(10), volatility FLOAT);
"""
cursor.execute(create_table_query)
conn.commit()

#  Load the CSV
csv_path = r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\volatility.csv"
df = pd.read_csv(csv_path)

#  Convert DataFrame to list of tuples
data = list(df.itertuples(index=False, name=None))

#  Insert data
insert_query = "INSERT INTO volatility_analysis (ticker, volatility) VALUES (%s, %s)"

batch_size = 10
for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    try:
        cursor.executemany(insert_query, batch)
        conn.commit()
        print(f" Inserted {min(i + batch_size, len(data))} rows successfully.")
    except mysql.connector.Error as e:
        print(f" Error inserting batch {i}-{i + batch_size}: {e}")

#  Close connection
cursor.close()
conn.close()

print(" Volatility data successfully inserted into SQL database!")
# Out:
#  Inserted 10 rows successfully.
#  Inserted 20 rows successfully.
#  Inserted 30 rows successfully.
#  Inserted 40 rows successfully.
#  Inserted 50 rows successfully.
#  Volatility data successfully inserted into SQL database!

# %%
import mysql.connector
import pandas as pd
#  Database Connection
conn = mysql.connector.connect(
host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
port=4000,
user="4DqqoiZXMnHx5MN.root",
password="3wJPqKRiThuBOBDz",
database="Stock",
ssl_disabled=False # Required for secure connection
)
cursor = conn.cursor()

#Step 1: Create Table for Cumulative Returns
create_table_query = """
CREATE TABLE IF NOT EXISTS cumulative_returns ( date DATE, ticker VARCHAR(20), cumulative_return FLOAT
);
"""
cursor.execute(create_table_query)
conn.commit()

#  Step 2: Read CSV File
df = pd.read_csv(r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\cumulative_returns.csv")

#  Step 3: Convert date column to proper format (if needed)
df['date'] = pd.to_datetime(df['date']).dt.date

#  Drop rows with missing values
df.dropna(subset=['date', 'symbol', 'cumulative_return'], inplace=True)

#  Step 4: Convert DataFrame to List of Tuples
data = list(df.itertuples(index=False, name=None))

#  Step 5: Insert in Batches
insert_query = "INSERT INTO cumulative_returns (date, ticker, cumulative_return) VALUES (%s, %s, %s)"
batch_size = 500

for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    try:
        cursor.executemany(insert_query, batch)
        conn.commit()
        print(f" Inserted {min(i + batch_size, len(data))} rows successfully.")
    except mysql.connector.Error as e:
        print(f" Error inserting batch {i}-{i + batch_size}: {e}")

#  Step 6: Close Connection
cursor.close()
conn.close()

print(" Cumulative returns data inserted successfully!")
# Out:
#  Inserted 500 rows successfully.
#  Inserted 1000 rows successfully.
#  Inserted 1500 rows successfully.
#  Inserted 2000 rows successfully.
#  Inserted 2500 rows successfully.
#  Inserted 3000 rows successfully.
#  Inserted 3500 rows successfully.
#  Inserted 4000 rows successfully.
#  Inserted 4500 rows successfully.
#  Inserted 5000 rows successfully.
#  Inserted 5500 rows successfully.
#  Inserted 6000 rows successfully.
#  Inserted 6500 rows successfully.
#  Inserted 7000 rows successfully.
#  Inserted 7500 rows successfully.
#  Inserted 8000 rows successfully.
#  Inserted 8500 rows successfully.
#  Inserted 9000 rows successfully.
#  Inserted 9500 rows successfully.
#  Inserted 10000 rows successfully.
#  Inserted 10500 rows successfully.
#  Inserted 11000 rows successfully.
#  Inserted 11500 rows successfully.
#  Inserted 12000 rows successfully.
#  Inserted 12500 rows successfully.
#  Inserted 13000 rows successfully.
#  Inserted 13500 rows successfully.
#  Inserted 14000 rows successfully.
#  Inserted 14150 rows successfully.
#  Cumulative returns data inserted successfully!

# %%
import mysql.connector
import pandas as pd

#  Database Connection
conn = mysql.connector.connect(
host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
port=4000,
user="4DqqoiZXMnHx5MN.root",
password="3wJPqKRiThuBOBDz",
database="Stock",
ssl_disabled=False # Required for secure connection
)
cursor = conn.cursor()



#  Create table if not exists
create_table_query = """
CREATE TABLE IF NOT EXISTS sector_performance (sector VARCHAR(100), cumulative_return FLOAT
);
"""
cursor.execute(create_table_query)
conn.commit()

#  Load the CSV
df = pd.read_csv(r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\sector_performance.csv")

#  Drop missing values just in case
df.dropna(subset=['sector', 'cumulative_return'], inplace=True)

#  Convert to list of tuples
data = list(df.itertuples(index=False, name=None))

#  Insert query
insert_query = """
INSERT INTO sector_performance (sector, cumulative_return)
VALUES (%s, %s)
"""

#  Batch insert
batch_size = 10
for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    try:
        cursor.executemany(insert_query, batch)
        conn.commit()
        print(f" Inserted {min(i + batch_size, len(data))} rows successfully.")
    except mysql.connector.Error as e:
        print(f" Error inserting batch {i}-{i+batch_size}: {e}")

#  Close connection
cursor.close()
conn.close()

print(" Sector performance data inserted successfully!")
# Out:
#  Inserted 10 rows successfully.
#  Inserted 20 rows successfully.
#  Sector performance data inserted successfully!

# %%
import mysql.connector
import pandas as pd

#  Database Connection
conn = mysql.connector.connect(
host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
port=4000,
user="4DqqoiZXMnHx5MN.root",
password="3wJPqKRiThuBOBDz",
database="Stock",
ssl_disabled=False # Required for secure connection
)
cursor = conn.cursor()



#  Drop existing table if needed
cursor.execute("DROP TABLE IF EXISTS monthly_returns")

#  Create table
create_table_query = """
CREATE TABLE monthly_returns (ticker VARCHAR(20), month VARCHAR(10), monthly_return FLOAT
);
"""
cursor.execute(create_table_query)
conn.commit()
print(" Table 'monthly_returns' created.")

#  Load CSV
df = pd.read_csv(r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\monthly_returns.csv")

#  Drop missing values
df.dropna(subset=['ticker', 'month', 'return'], inplace=True)

#  Select only required columns in correct order
data = df[['ticker', 'month', 'return']].values.tolist()

#  Insert in batches
batch_size = 500
insert_query = """
INSERT INTO monthly_returns (ticker, month, monthly_return) VALUES (%s, %s, %s)
"""

for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    try:
        cursor.executemany(insert_query, batch)
        conn.commit()
        print(f" Inserted rows {i} to {i + len(batch)}")
    except mysql.connector.Error as e:
        print(f" Error inserting batch {i}-{i + batch_size}: {e}")

#  Close connection
cursor.close()
conn.close()
print(" Monthly returns data inserted successfully!")
# Out:
#  Table 'monthly_returns' created.
#  Inserted rows 0 to 14
#  Monthly returns data inserted successfully!

# %%
import mysql.connector
import pandas as pd

#  Database Connection
conn = mysql.connector.connect(
host="gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
port=4000,
user="4DqqoiZXMnHx5MN.root",
password="3wJPqKRiThuBOBDz",
database="Stock",
ssl_disabled=False # Required for secure connection
)
cursor = conn.cursor()



#  Drop table if exists
cursor.execute("DROP TABLE IF EXISTS correlation_matrix")

#  Create table
create_table_query = """
CREATE TABLE correlation_matrix (ticker1 VARCHAR(20), ticker2 VARCHAR(20), correlation FLOAT
);
"""
cursor.execute(create_table_query)
conn.commit()
print(" Table 'correlation_matrix' created.")

#  Load CSV
df = pd.read_csv(r"C:\Users\vishn\OneDrive\Desktop\project2\metrics_csv\correlation_matrix.csv",
index_col=0)

#  Reset index and assign column name manually
df.reset_index(inplace=True)
df.rename(columns={'index': 'ticker1'}, inplace=True) # In casecolumn is still named 'index'

#  Melt the DataFrame
correlation_long = pd.melt(df, id_vars=['ticker1'],
var_name='ticker2', value_name='correlation')

#  Drop NaNs
correlation_long.dropna(subset=['ticker1', 'ticker2', 'correlation'],
inplace=True)

#  Convert to list of tuples
data = correlation_long[['ticker1', 'ticker2', 'correlation']].values.tolist()

#  Insert in batches
batch_size = 500
insert_query = "INSERT INTO correlation_matrix (ticker1, ticker2, correlation) VALUES (%s, %s, %s)"

for i in range(0, len(data), batch_size):
    batch = data[i:i+batch_size]
    try:
        cursor.executemany(insert_query, batch)
        conn.commit()
        print(f" Inserted rows {i} to {i + len(batch)}")
    except mysql.connector.Error as e:
        print(f" Error inserting batch {i}-{i + batch_size}: {e}")

#  Close connection
cursor.close()
conn.close()
print(" Correlation matrix data inserted successfully!")
# Out:
#  Table 'correlation_matrix' created.
#  Inserted rows 0 to 500
#  Inserted rows 500 to 1000
#  Inserted rows 1000 to 1500
#  Inserted rows 1500 to 2000
#  Inserted rows 2000 to 2500
#  Correlation matrix data inserted successfully!
